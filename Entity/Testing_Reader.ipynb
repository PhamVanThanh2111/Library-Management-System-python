# %%
from Reader import Reader
from ReaderList import ReaderList

# 2.1.      Load data from file
readerList = ReaderList()
readerList.load_from_csv("../Data/readers.csv")
readerList.display_readers()
# Out:
# rcode: R001
# name: John Doe
# byear: 1990
#
# rcode: R002
# name: Alice Smith
# byear: 1985
#
# rcode: R003
# name: Michael Johnson
# byear: 1978
#
# rcode: R004
# name: Emily Brown
# byear: 1992
#
# rcode: R005
# name: David Wilson
# byear: 1980
#
# rcode: R006
# name: Sarah Jones
# byear: 1987
#
# rcode: R007
# name: Christopher Taylor
# byear: 1995
#
# rcode: R008
# name: Emma Martinez
# byear: 1976
#
# rcode: R009
# name: James Anderson
# byear: 1998
#
# rcode: R010
# name: Sophia Garcia
# byear: 1983
#
# rcode: R011
# name: Matthew Rodriguez
# byear: 1989
#
# rcode: R012
# name: Olivia Hernandez
# byear: 1991
#
# rcode: R013
# name: William Lopez
# byear: 1979
#
# rcode: R014
# name: Isabella Gonzalez
# byear: 1986
#
# rcode: R015
# name: Ethan Perez
# byear: 1993
#
# rcode: R016
# name: Ava Lee
# byear: 1982
#
# rcode: R017
# name: Alexander Scott
# byear: 1977
#
# rcode: R018
# name: Mia Walker
# byear: 1997
#
# rcode: R019
# name: Daniel Hall
# byear: 1984
#
# rcode: R020
# ...

# %%
# 2.2.      Input & add to the end
readerList.insert_to_csv(Reader("R031", "Pham Van Thanh", 2003))

# %%
# 2.3.      Display data
readerList.display_readers()
# Out:
# rcode: R001
# name: John Doe
# byear: 1990
#
# rcode: R002
# name: Alice Smith
# byear: 1985
#
# rcode: R003
# name: Michael Johnson
# byear: 1978
#
# rcode: R004
# name: Emily Brown
# byear: 1992
#
# rcode: R005
# name: David Wilson
# byear: 1980
#
# rcode: R006
# name: Sarah Jones
# byear: 1987
#
# rcode: R007
# name: Christopher Taylor
# byear: 1995
#
# rcode: R008
# name: Emma Martinez
# byear: 1976
#
# rcode: R009
# name: James Anderson
# byear: 1998
#
# rcode: R010
# name: Sophia Garcia
# byear: 1983
#
# rcode: R011
# name: Matthew Rodriguez
# byear: 1989
#
# rcode: R012
# name: Olivia Hernandez
# byear: 1991
#
# rcode: R013
# name: William Lopez
# byear: 1979
#
# rcode: R014
# name: Isabella Gonzalez
# byear: 1986
#
# rcode: R015
# name: Ethan Perez
# byear: 1993
#
# rcode: R016
# name: Ava Lee
# byear: 1982
#
# rcode: R017
# name: Alexander Scott
# byear: 1977
#
# rcode: R018
# name: Mia Walker
# byear: 1997
#
# rcode: R019
# name: Daniel Hall
# byear: 1984
#
# rcode: R020
# ...

# %%
# 2.4.      Save reader list to file
readerList.save_to_file("../Data/readers_new.csv")

# %%
# 2.5.      Search by rcode
readerList.search("R031").name
# Out:
# 'Pham Van Thanh'

# %%
# 2.6.      Delete by rcode
readerList.delete("R031")
readerList.display_readers()
# Out:
# rcode: R001
# name: John Doe
# byear: 1990
#
# rcode: R002
# name: Alice Smith
# byear: 1985
#
# rcode: R003
# name: Michael Johnson
# byear: 1978
#
# rcode: R004
# name: Emily Brown
# byear: 1992
#
# rcode: R005
# name: David Wilson
# byear: 1980
#
# rcode: R006
# name: Sarah Jones
# byear: 1987
#
# rcode: R007
# name: Christopher Taylor
# byear: 1995
#
# rcode: R008
# name: Emma Martinez
# byear: 1976
#
# rcode: R009
# name: James Anderson
# byear: 1998
#
# rcode: R010
# name: Sophia Garcia
# byear: 1983
#
# rcode: R011
# name: Matthew Rodriguez
# byear: 1989
#
# rcode: R012
# name: Olivia Hernandez
# byear: 1991
#
# rcode: R013
# name: William Lopez
# byear: 1979
#
# rcode: R014
# name: Isabella Gonzalez
# byear: 1986
#
# rcode: R015
# name: Ethan Perez
# byear: 1993
#
# rcode: R016
# name: Ava Lee
# byear: 1982
#
# rcode: R017
# name: Alexander Scott
# byear: 1977
#
# rcode: R018
# name: Mia Walker
# byear: 1997
#
# rcode: R019
# name: Daniel Hall
# byear: 1984
#
# rcode: R020
# ...
